# %%
## YOUR CODE HERE
# Imports 
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import seaborn as sns
sns.set()
sns.set_context('talk')

import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", 104)
import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION
df_year = pd.read_csv('https://raw.githubusercontent.com/COGS108/Group065Sp22/master/data/table_12.csv?token=GHSAT0AAAAAABSAKWHAGXYCQOECXJRDKU7OYTUKCZQ')
df_year
# Out:
#     Year  Total   16 to 24 years  16 to 19 years  20 to 24 years  \
# 0   1979    62.3            78.6            85.2            76.3
# 1   1980    64.2            80.3            89.5            78.1
# 2   1981    64.4            82.6            91.7            80.6
# 3   1982    65.7            85.3            92.9            82.4
# 4   1983    66.5            88.8            94.0            85.5
# 5   1984    67.6            87.9            93.1            85.2
# 6   1985    68.1            87.6            90.7            85.7
# 7   1986    69.5            89.0            91.4            87.5
# 8   1987    69.8            88.3            87.8            88.0
# 9   1988    70.2            89.7            89.8            90.0
# 10  1989    70.1            90.8            94.3            89.7
# 11  1990    71.9            90.1            90.8            90.3
# 12  1991    74.2            93.3            93.6            93.3
# ...

# %%
df_race = pd.read_csv('https://raw.githubusercontent.com/COGS108/Group065Sp22/master/data/Table_13.csv?token=GHSAT0AAAAAABSAKWHBMENOU6IKC3HMSTJQYTUKBPQ')
df_race
# Out:
#     Year  Total,16 years and older  White  Black or African American Asian  \
# 0   1979                      62.3   61.7                       74.4     –
# 1   1980                      64.2   63.4                       75.8     –
# 2   1981                      64.4   63.1                       76.9     –
# 3   1982                      65.7   64.5                       78.1     –
# 4   1983                      66.5   65.6                       78.9     –
# 5   1984                      67.6   66.8                       79.5     –
# 6   1985                      68.1   67.2                       82.6     –
# 7   1986                      69.5   67.9                       82.8     –
# 8   1987                      69.8   68.2                       84.4     –
# 9   1988                      70.2   68.4                       82.8     –
# 10  1989                      70.1   69.3                       86.5     –
# ...

# %%
df_education = pd.read_csv('https://raw.githubusercontent.com/COGS108/Group065Sp22/master/data/Table_14.csv?token=GHSAT0AAAAAABSAKWHAP3DGR5UKNUJWD3ZMYTUKDOA')
df_education
# Out:
#     Year  Total, 25 years and older  Less than a high school diploma  \
# 0   1979                       62.1                             60.3
# 1   1980                       62.8                             61.4
# 2   1981                       62.6                             61.2
# 3   1982                       64.9                             62.8
# 4   1983                       65.8                             64.8
# 5   1984                       67.1                             64.9
# 6   1985                       66.8                             64.3
# 7   1986                       66.5                             64.8
# 8   1987                       67.3                             66.0
# 9   1988                       68.8                             66.6
# 10  1989                       70.2                             66.8
# 11  1990                       72.1                             68.8
# 12  1991                       74.0                             71.6
# ...

# %%
wage = df_year.merge(df_race, on = 'Year')
wage = wage.merge(df_education, on = 'Year')
wage
# Out:
#     Year  Total   16 to 24 years  16 to 19 years  20 to 24 years  \
# 0   1979    62.3            78.6            85.2            76.3
# 1   1980    64.2            80.3            89.5            78.1
# 2   1981    64.4            82.6            91.7            80.6
# 3   1982    65.7            85.3            92.9            82.4
# 4   1983    66.5            88.8            94.0            85.5
# 5   1984    67.6            87.9            93.1            85.2
# 6   1985    68.1            87.6            90.7            85.7
# 7   1986    69.5            89.0            91.4            87.5
# 8   1987    69.8            88.3            87.8            88.0
# 9   1988    70.2            89.7            89.8            90.0
# 10  1989    70.1            90.8            94.3            89.7
# 11  1990    71.9            90.1            90.8            90.3
# 12  1991    74.2            93.3            93.6            93.3
# ...

# %%
wage.shape
# Out:
# (41, 21)

# %%
wage.isna().any()
# Out:
# Year                                 False
# Total                                False
# 16 to 24 years                       False
# 16 to 19 years                       False
# 20 to 24 years                       False
# 25 to 65 years                       False
# 25 to 34 years                       False
# 35 to 44 years                       False
# 45 to 54 years                       False
# 55 to 64 years                       False
# 65 years and older                   False
# Total,16 years and older             False
# White                                False
# Black or African American            False
# Asian                                False
# Hispanic or Latino ethnicity         False
# Total, 25 years and older            False
# Less than a high school diploma      False
# High school graduates, no college    False
# Some college or associate degree     False
# Bachelor's degree and higher         False
# dtype: bool
